# %% [markdown]
# ## Name:

# %% [markdown]
# **Instructions:** Please submit a Jupyter notebook (html or pdf) answering the following parts.
#
# This homework is due **Friday, Oct. 21 by 11:59PM**.
#
# * Make sure you have a table of contents, appropriate headings, and comments on your code
#
# * If you collaborate with someone in the class, note the name on the assignment.

# %% [markdown]
# Table of Contents:
#    * [What do I watch next?](#movie-rec)
#    * [More SVD please!](#svd)
#    * [Read Between the LInES](#linear-regression)

# %%
# import necessary packages 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from imageio import imread
from skimage import data
# import more packages below

# %% [markdown]
# ## Movie Recommendations <a id="movie-rec"></a>
#
# **a)** Write a function that takes in 2 inputs and calculates the cosine similarity between the two inputs.

# %% [markdown]
# **b)** Download (if you have not done so already) and load the `users.dat` data file and load it as
#
# ```
# users = pd.io.parsers.read_csv(path + 'users.dat', engine='python',
#                                names=['user_id','gender','age','occupation','zip_code'],
#                                delimiter='::')
# ```
#
# see <a href="https://github.com/srp98/Movie-Recommender-using-RBM/tree/master/ml-1m"> here </a> for a description of the data.
#
# Create at least 2 visualizations with this data. Note at least two observations from your visualizations.

# %% [markdown]
# **c)** Now load the `movies.dat` and `ratings.dat`. In lecture, we recommended movies based on other movies. Now, create a user-based recommendation system where you report the cosine similarity between users.
#
# For example, if I input a `user_id`, I should be recommended the `top_n` users who have similar preferences.

# %% [markdown]
# **d)** Pick a random user from each of the following ranges:
#
#     * 1:  "Under 18"
# 	* 18:  "18-24"
# 	* 25:  "25-34"
# 	* 35:  "35-44"
# 	* 45:  "45-49"
# 	* 50:  "50-55"
# 	* 56:  "56+"
#
# and report the top 10 similar users. Are similar users in the same age ranges or different age ranges? Include a visualization to support your conclusion.

# %% [markdown]
# ## More on the SVD  <a id="svd"></a>
#
#
# **a)** When considering the SVD for an $m \times n$ matrix $A$, we can calculate the elements of $U$ (from $A = U\Sigma V^T$) by defining the the vectors $\vec{u_i} = \frac{A \vec{v_i}}{\sigma_i}$, and then note that
#
# $$
# U = A V \Sigma^{-1}
# $$
#
# Prove that the vector $\vec{u_i}$ is an eigenvector of $AA^T$.

# %% [markdown]
# **b)** Prove that $\vec{u_i}$ has unit length.

# %% [markdown]
# **c)** Show that the SVD of $A$ can be written as a sum of rank-1 matrices.

# %% [markdown]
# **d)** We know that $M = A^TA$ is a symmetric matrix. Using the definition of eigenvalues and eigenvectors, show that any symmetric matrix only has real eigenvalues.

# %% [markdown]
# **e)** Letting $M = A^TA$, and assuming that $\vec{x}^T M \vec{x} \ge \vec{0}$ for any vector $\vec{x}$. Use the definition of eigenvalues and eigenvectors to show that all the eigenvalues of $M$ are non negative (and by part **d)**, real).
#
# **Note:** This is why we state that the singular values of $A,\; \sigma_i$ ($\sigma_i^2 = \lambda_i$) are also real and non-negative (chosen to be positive part of square root), since we have shown that $\lambda_i$ are real and non-negative.

# %% [markdown]
# **f) BONUS LEVEL - Optional**
#
# ![star](https://camo.githubusercontent.com/05ada631159679cf023aacdfb67edbaacc5c5a07/68747470733a2f2f6d656469612e67697068792e636f6d2f6d656469612f37354c62667972636d664f70322f67697068792e676966)
#
# Prove the other direction of part **e)** (if you know the eigenvalues are real and non negative, show that $\vec{x}^T M \vec{x} \ge \vec{0}$ for any vector $\vec{x}$.

# %% [markdown]
# ## Linear Regression  <a id="linear-regression"></a>
#
# **a)** Read **through and implement** this <a href="https://towardsdatascience.com/linear-regression-in-6-lines-of-python-5e1d0cd05b8d"> Linear Regression article.</a> You will have to download (and load) the data in order for this to work.

# %% [markdown]
# **b)** Note that we are trying to solve a $A\vec{x} = \vec{b}$ problem. Multiply both sides of this equation by $A^T$. What can you do to simplify/solve for $\vec{x}$ (hint: what is the main theme of this hw)?

# %% [markdown]
# **c)** With the data from the article, implement the gradient descent method (by writing your own) to estimate the intercept and slope.
