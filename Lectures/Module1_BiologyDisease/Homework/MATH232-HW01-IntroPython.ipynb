# %% [markdown]
# # MATH 232 - Homework 01

# %% [markdown]
# ## Name:

# %% [markdown]
# **Instructions:** Please submit a Jupyter notebook (html or pdf) answering the following parts.
#
# This homework is due **Wednesday, Aug 31 by 11:59PM**.
#
# * Make sure you have a table of contents, appropriate headings, and comments on your code
#
# * If you collaborate with someone in the class, note the name on the assignment.

# %% [markdown]
# Table of Contents:
#    * [Intro to Python](#part1)
#        * [Assigned Reading](#read)
#        * [Exponential Growth](#exp)
#    * [Intro to Data Ethics](#ethics)
#    * [Modeling](#part2)
#        * [Running](#run)
#        * [Elevator](#elevate)
#        * [Crowd Counting](#crowd)

# %%
# import necessary packages
# importing numpy as np is just a short-cut name
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %% [markdown]
# # Intro to Python <a id='part1'></a>

# %% [markdown]
# ## Assigned Reading <a id='read'></a>

# %% [markdown]
# - Read **Sections 1.1, 1.6, 1.7, 2.7 - 2.9, and Chapter 3**  in the <a href="http://greenteapress.com/thinkpython2/thinkpython2.pdf">ThinkPython Book </a>
# - Provide a summary and a Python example  of the following terms/concepts:
#           - Debugging
#           - Flow of execution
#           - Parameters and arguments
#           - Fruitful and void functions

# %% [markdown]
# ## Exponential Growth <a id='exp'></a>

# %% [markdown]
# Use the following code to create 2 different functions (**one discrete, one continuous**) that:
#    * takes in $t$, $n_0$, and $r$ as arguments and outputs the population size, i.e.,
#
#        `discrete_fun(t=30,n0=1,r=1)` returns an output
#
#    * test each of your functions on different 3 different values of $r$. Save the outputs of the function to a new variable.
#    * create two plots (**one discrete, one continuous**) with the 3 different values of $r$ you chose. Make sure to label and title your plots.

# %%
t = np.linspace(0,50)
r1 = 1
r2 = 0.1
n0 = 1
n_cont1 = np.exp(r1*t) * n0
n_cont2 = np.exp(r2*t) * n0
n_disc1 = (1+r1)**(t) * n0
n_disc2 = (1+r2)**(t) * n0

# %% [markdown]
# # Intro to Data Ethics <a id='ethics'></a>
#
# Read Part Three (p. 29-34) and Part Five (p. 48-56) of the An **Introduction to Data Ethics** pdf and answer
#
# Questions 3.3, 3.4, 3.5, 3.6, 5.1, 5.2, and 5.3 in this document.

# %% [markdown]
# **Question 3.3.**
# What specific, significant harms to members of the public did the researchers’ actions risk? List as many types of harm as you can think of.

# %% [markdown]
# **Question 3.4.**
# How should those potential harms have been evaluated alongside the prospective benefits of the research claimed by the study’s authors? Could the benefits hoped for by the authors have been significant enough to justify the risks of harm you identified above in 3.3?

# %% [markdown]
# **Question 3.5.**
# List the various stakeholders involved in the OkCupid case, and for each type of stakeholder you listed, identify what was at stake for them in this episode. Be sure your list is as complete as you can make it, including all possible affected stakeholders.

# %% [markdown]
# **Question 3.6.**
# The researchers’ actions potentially affected tens of thousands of people. Would the members of the public whose data were exposed by the researchers be justified in feeling abused, violated, or otherwise unethically treated by the study’s authors, even though they have never had a personal interaction with the authors? If those feelings are justified, does this show that the study’s authors had an ethical obligation to those members of the public that they failed to respect?

# %% [markdown]
# **Question 5.1.**
# Of these fourteen best practices for data ethics, which two do you think are the most challenging to carry out? What do you think could be done (by an individual, a team, or an organization) to make those practices easier?

# %% [markdown]
# **Question 5.2.**
# What benefits do you think might come from successfully instituting these practices in data environments—for society overall, and for big data professionals?

# %% [markdown]
# **Question 5.3.**
# Of these five moral habits and practices, which do you think you are best at presently? Which of these habits, if any, would you like to do more to cultivate?

# %% [markdown]
# # Modeling <a id='part2'></a>

# %% [markdown]
# ## Running <a id='run'></a>
#
# If I leave my house at 5:53 am and run 1 mile at an easy pace (9:15 per mile), then 3 miles at a faster pace (8:04 per mile) and 1 mile at easy pace again, what time do I get home for breakfast?
#
# Attempt to create a plot in Python to support your solution.

# %% [markdown]
# ## Elevator <a id='elevate'></a>
# How many people can you fit in an elevator? You may refer to the modeling process, but be sure to explain your specific method and show your mathematical logic.

# %% [markdown]
# ## Crowd Counting <a id='crowd'></a>
#
# Read or listen to the following article: https://www.npr.org/sections/thetwo-way/2017/01/23/511267138/politics-aside-counting-crowds-is-tricky
#
# and answer the following:
#
# * How were your approaches similar to and different from the estimation techniques presented in the article?
# * What ethical benefits or challenges exist in this mathematical model?
