# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mbanuelos/grad_math_modeling/blob/main/Lectures/Module3_DeepLearning/20_IntroGoogleColab_FastAI.ipynb)

# %% [markdown]
# # MATH 232 - Math Models w/ Tech
# ## Introduction to Google Colab & FastAI
# ### Instructor: Prof. Mario Bañuelos

# %% [markdown]
# # On a scale from 0 - 5, rate your social/emotional health today. You may send this number in the chat (privately or publicly)

# %% [markdown]
# ## Outline
#  - [FastAI](#fastai)
#  - [Google Colab](#colab)
#  - [Further Reading](#reading)
# ***

# %% [markdown]
# ## FastAI  <a id='fastai'> </a>
#
# * FastAI is a library that simplifies training neural networks
# * It has models that are predefined for a variety of tasks
# * Started by <a href="https://www.fast.ai/about/#jeremy"> Jeremy Howard and Rachel Thomas </a>

# %% [markdown]
# ## Google Colab <a id='colab'></a>
#
# * Colab is a Python development environment that runs in the browser using Google Cloud.
# * Works very similar to running Jupyter Notebooks on your machine.
# * You can start by navigating to https://colab.research.google.com/

# %% [markdown]
# ## Further Reading <a id="reading"></a>
#
#
# * <a href="https://towardsdatascience.com/intro-to-fastai-installation-and-building-our-first-classifier-938e95fd97d3"> MNIST w/ FastAI </a>
# * <a href="https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035"> An Overview of ResNet and variants </a>
# * <a href="https://course.fast.ai/videos/?lesson=1"> FastAI Lesson 1 (2020) </a>
