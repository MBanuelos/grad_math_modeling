# %% [markdown]
# # MATH 232 - Homework 03

# %% [markdown]
# ## Name:

# %% [markdown]
# **Instructions:** Please submit a Jupyter notebook (html or pdf) answering the following parts.
#
# This homework is due **Wednesday, Sept. 14th by 11:59PM**.
#
# * Make sure you have a table of contents, appropriate headings, and comments on your code
#
# * If you collaborate with someone in the class, note the name on the assignment.

# %% [markdown]
# Table of Contents:
#    * [ODE - Midterm 1 Topic](#ode-midterm)
#    * [Lotka-Volterra](#lotka-volterra)

# %%
# import necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from IPython.display import HTML, IFrame

# %% [markdown]
# # ODE - Midterm 1 Topic
#
# For the first midterm, you will be submitting a Jupyter notebook as well as 5-7 minute presentation (further details will be posted on Canvas).
#
# For this problem, you will choose a topic by completing <a href="https://forms.gle/NPY5Daie5yiKpYhR9"> this Google Form </a>. If you have a topic in mind (that is not listed below), please contact me for topic approval. The topics on the form include:
#
# * Competitive Lotka–Volterra equations
# * Theta-Logistic Growth Models
# * SEIR model (epidemiological model)
# * SIS model (epidemiological model)
# * Newton's Law of Cooling
# * Cascading Tanks (water flowing from one tank to another)
#
#
# **NOTE: There will be a maximum of 2 people per topic.**
#
# **This will be determined by a first-come, first-serve process.**

# %% [markdown]
# After choosing your topic, you probably will have the last question completed (since we are studying existing models). With this in mind, please address the following questions for your topic (each response should be at least a couple sentences in length but not exceeding more than a paragraph):
#
#
# 1. What is being modeled? Why did people want to model it?
#
#
# 2. Clearly define **success** in the context of this model. What bias may have been introduced or already exists?
#
#
# 3. Research similar models in the literature. What has been done previously? Searching for a review paper is a good start for this question.
#
#
# 4. State key assumptions needed to build the model. Define any parameters in the model.
#
#
# 5. Mathematically formulate your model.

# %% [markdown]
# # Lotka-Volterra (Predator & Prey) <a id='lotka-volterra'></a>
#
#
# ## Simple Lotka-Volterra
#
# An example of predator-prey system is that of the Galapagos tortoise and the cactus plants that grow on the <a href=https://necsi.edu/galapagos>Galapagos islands</a>.
#
# Let $C$ represent the number of cacti and $T$ the number of tortoises (both in 1000s). Assume that the model for their interaction is given by:
#
# $$
# T' = −4T + 2TC,\quad C' = 3C - 2TC,
# $$
#
# where the $TC$-term is a measure of the interaction between the two species.

# %% [markdown]
# **a)** Show that the system has an equilibrium point at (1.5, 2).

# %% [markdown]
# **b)** Numerically solve this system for 3 different initial conditions (you choose). Plot all 6 solutions on the same plot (make sure to add appropriate labels). What conclusions can you draw?

# %% [markdown]
# **c)** Calculate the Jacobian $J$ and evaluate it at the equilibrium point. What can you conclude about the eigenvalues?

# %% [markdown]
# ## Modified Lotka-Volterra
#
# In a slightly modified predator-prey system
#
# $$
# T' = −4T + 2TC,\quad C' = 3\left(1- \frac{C}{K}\right)C - 2TC,
# $$
#
# the number $K$ represents the carrying capacity of the cacti. Choose a value of $K$ and
#
# $\Rightarrow$ Repeat **a) - c)** for this new system.

# %% [markdown]
# **d)** Investigate the effect of changing the value of $K$. What’s the largest the tortoise population can get? The cacti population?

# %% [markdown]
# **e)** If another predator was added, write down what you think the resulting ODEs would look like. Explain your assumptions and any terms that have not been previously defined.
