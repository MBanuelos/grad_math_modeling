# %% [markdown]
# ## Name:

# %% [markdown]
# **Instructions:** Please submit a Jupyter notebook (html or pdf) answering the following parts.
#
# This homework is due **Wednesday, Nov. 9 by 11:59PM**.
#
# * Make sure you have a table of contents, appropriate headings, and comments on your code
#
# * If you collaborate with someone in the class, note the name on the assignment.

# %% [markdown]
# Table of Contents:
#    * [Life Is Not an Energy Shield (LINES)](#linear-reg)
#    * [PCR vs Subset Selection](#pcr-sub)

# %%
# import necessary packages 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from imageio import imread
from skimage import data
# import more packages below

# %% [markdown]
# ## Energy Consumption <a id="linear-reg"></a>
#
# In this exercise, you will navigate to the UC Irvine Machine Learning Repository and import data used to predict energy consumption.

# %% [markdown]
# a) Navigate <a href="https://archive.ics.uci.edu/ml/datasets/Energy+efficiency"> here </a> and download the Energy Efficiency data.

# %% [markdown]
# b) Provide a description of the data as well as the name of the study that should be cited if the data is used.

# %% [markdown]
# c) Load the data into Python.

# %% [markdown]
# d) Which of the predictors are quantitative and which are qualitative?

# %% [markdown]
# e) Produce some histograms with differing number of bins for two quantitative columns.

# %% [markdown]
# f) Make some pairwise scatterplots of the predictors in this data set. Describe your findings.

# %% [markdown]
# g) Create a testing and training set with the data. Then, implement forward-subset selection and report the best model.

# %% [markdown]
# ## PCR vs Subset Selection. <a id="pcr-sub"></a>
#
# Load a data set from the `datasets` submodule/package (from `sklearn`) that you can use for linear regression and complete the following:
#
#  1. What do the columns in this data represent?
#  2. What does $Y$ represent?
#  3. What would success mean in the context of this model?
#  4. What are some ethically significant challenges and benefits from creating a models with this data?
#  5. Create some visualizations and note any observations.
#  6. Using K-fold CV, use **one** subset selection method and PCR to create regression models. Calculate the MSE for the models you created and report them in a table.
#  7. What are conclusions you can draw from your regression analysis?
