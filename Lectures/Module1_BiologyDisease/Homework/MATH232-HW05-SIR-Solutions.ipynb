# %% [markdown]
# # MATH 232 - Homework 05

# %% [markdown]
# ## Name:

# %% [markdown]
# **Instructions:** Please submit a Jupyter notebook (html or pdf) answering the following parts.
#
# This homework is due **Friday, Sept. 30 by 11:59PM**.
#
# * Make sure you have a table of contents, appropriate headings, and comments on your code
#
# * If you collaborate with someone in the class, note the name on the assignment.

# %% [markdown]
# Table of Contents:
#    * [SIR with vital dynamics](#sir-vital)
#    * [SIR and COVID-19](#sir-covid)

# %%
# import necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from IPython.display import HTML, IFrame

# %% [markdown]
# ## SIR with vital dynamics <a id="sir-vital"></a>
#
# Beginning with the SIR model, we will now add a couple more assumptions:
#
# * birth occurs at a constant rate ($\mu$) and they are immediately added to the Susceptible compartment, leading to
#
# $$
# S' = \mu - \beta S I
# $$
#
# * natural death occurs at each compartment, according to
#
# $$
# \begin{align*}
# S \overset{\mu}{\rightarrow} \emptyset \\
# I \overset{\mu}{\rightarrow} \emptyset \\
# R \overset{\mu}{\rightarrow} \emptyset \\
# \end{align*}
# $$

# %% [markdown]
# **a)** With these 2 additional assumptions, write down the SIR model with vital dynamics

# %% [markdown]
# We have
#
# $$
# S' = \mu - S(\beta I + \mu)\\
# I' = I(\beta S - \mu - \gamma)\\
# R' = \gamma I - \mu R
# $$

# %% [markdown]
# **b)** Show that $R_0 = \frac{\beta}{\gamma + \mu}$.

# %% [markdown]
# If $I' < 0$ initially (with $I > 0$), we would require that $\beta S - \mu - \gamma < 0$
#
#
# $\Rightarrow \mu + \gamma > \beta S  \Rightarrow 1 > \frac{\beta}{\gamma + \mu} S$, which means there will not be an epidemic as long as $R_0 S < 1$

# %% [markdown]
# **c)** Show that the disease-free equilbrium is $(1,0,0)$ and the epidemic equilibrium is $\left(\frac{\gamma +\mu }{\beta}, \frac{\mu}{\beta}(R_0 - 1), \frac{\gamma}{\beta}(R_0 - 1) \right)$

# %% [markdown]
# **d)** Under what conditions is the epidemic equilibrium locally stable?

# %% [markdown]
# **e)** Use the values for $\gamma$ and $\beta$ from Lecture 07. Numerically solve this system. Investigate the role $\mu$ plays in the dynamics.

# %% [markdown]
# ## SIR - COVID-19 <a id="sir-covid"></a>
#
# Read and provide a brief summary (and reflection) of the following <a href="https://reader.elsevier.com/reader/sd/pii/S0960077920302411?token=02F176D6897A802D831B0F8C0323F2EE26528A7FCB708A1DC758ECBABF9FD52E0E67474A5EDFB8E0BA3FB60177EB2135"> paper</a>   (300 - 500 words).
#
# Some tips for reading a research paper:
#
# * Read the Abstract, then the Introduction, then the Conclusion. This way you get a sense of what the authors wanted to show and how they showed it.
#
# * Try to understand the Figures in the paper next. Do those figures support the conclusion?
#
# * Read the remaining parts.
