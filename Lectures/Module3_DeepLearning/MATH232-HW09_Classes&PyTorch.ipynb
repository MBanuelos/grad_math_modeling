# %% [markdown]
# ## Name:

# %% [markdown]
# **Instructions:** Please submit a Jupyter notebook (html or pdf) answering the following parts.
#
# This homework is worth 20 points and is due **Wed, Nov. 30 by 11:59PM**.
#
# * Make sure you have a table of contents, appropriate headings, and comments on your code
#
# * If you collaborate with someone in the class, note the name on the assignment.

# %% [markdown]
# Table of Contents:
#    * [Assigned Reading - ThinkPython2](#classes)
#        * [Circles](#circles)
#        * [Kangaroos](#kangaroos)
#    * [Multiple Linear Regression in PyTorch](#lin-reg)
#    * [Neural Networks](#nn)

# %%
# import necessary packages 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from imageio import imread
from skimage import data
# import more packages below

# %% [markdown]
# ## Classes & Object-Oriented Programming <a id="classes"></a>
#
# - From the <a href="https://greenteapress.com/thinkpython2/thinkpython2.pdf"> ThinkPython Book </a>, read **Chapter 15** (p. 147 - 153), **Chapter 16** (p. 155 - 160, and **Chapter 17** (p. 161 - 169). Then complete the following 2 exercises (they are also both from the ThinkPython Book).

# %% [markdown]
# ### Circles <a id="circles"></a>
#
# a) Write a definition for a class named `Circle` with attributes center and radius, where center is a `Point` object and radius is a number.

# %% [markdown]
# b) Instantiate a `Circle` object that represents a circle with its center at (150, 100) and radius 75.

# %% [markdown]
# c) Write a function named `point_in_circle` that takes a `Circle` and a `Point` and returns `True` if the `Poin`t lies in or on the boundary of the circle.

# %% [markdown]
# d) Write a function named `rect_in_circle` that takes a `Circle` and a `Rectangle` and returns `True` if the Rectangle lies entirely in or on the boundary of the circle.

# %% [markdown]
# e) Write a function named `rect_circle_overlap` that takes a `Circle` and a `Rectangle` and returns `True` if any of the corners of the Rectangle fall inside the circle. Or as a more challenging version, return `True` if any part of the Rectangle falls inside the circle.

# %% [markdown]
# ### Kangaroos <a id="kangaroos"></a>
#
# This exercise is a cautionary tale about one of the most common, and difficult to find, errors in Python. Write a definition for a class named Kangaroo with the following methods:
#
# a) An `__init__` method that initializes an attribute named pouch_contents to an empty list.

# %% [markdown]
# b) A method named `put_in_pouch` that takes an object of any type and adds it to
# pouch_contents.

# %% [markdown]
# c) A `__str__` method that returns a string representation of the Kangaroo object and the con- tents of the pouch.

# %% [markdown]
# Test your code by creating two Kangaroo objects, assigning them to variables named kanga and roo, and then adding roo to the contents of kanga’s pouch.
#
# Download http://thinkpython2.com/code/BadKangaroo.py . It contains a solution to the previous problem with one big, nasty bug. Find and fix the bug.
#
# If you get stuck, you can download http://thinkpython2.com/code/GoodKangaroo.py , which explains the problem and demonstrates a solution.

# %% [markdown]
# ## Multiple Linear Regression in PyTorch <a id="lin-reg"></a>
#
# Create simulated data with at least 2 features ($x_1$ and $x_2$) and one quantitative response ($y$). Implement gradient descent in PyTorch to calculate the intercept and 2 parameters.
#
# In your implementation, include a figure of iterations vs estimated value for each parameter. Note any observations based on these figures.

# %% [markdown]
# ## Neural Networks <a id="nn"></a>
#
# Watch the following <a href="https://youtube.com/playlist?list=PLZHQObOWTQDNU6R1_67000Dx_ZCJB-3pi">videos</a> and write a brief 300 - 1000 word summary about the videos. Be sure to include a reflection on what you thought about deep learning before this module and after completing one of the last homework assignments.
